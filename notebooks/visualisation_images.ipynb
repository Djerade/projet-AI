# %% [markdown]
# # ================================================================
# # Notebook : Visualisation des images NIfTI triées
# # ================================================================

# %%
import os
import nibabel as nib
import matplotlib.pyplot as plt

# %%
# ------------------------------------
# 📌 Paramètres
# ------------------------------------
# Chemin vers ton dossier de résultats (à modifier selon ton PC)
RESULTS_DIR = "/home/perfect/Documents/GitHub/projet-AI/data_filter"

# ------------------------------------
# 🔹 Fonction pour charger un NIfTI
# ------------------------------------
def load_nifti(file_path):
    """
    Charge un fichier NIfTI (.nii.gz) et retourne :
    - data : tableau numpy (image)
    - img : objet NIfTI (contient affine et header)
    """
    img = nib.load(file_path)
    data = img.get_fdata()
    return data, img

# %%
# ------------------------------------
# 🔹 Fonction pour afficher une coupe centrale
# ------------------------------------
def display_middle_slice(data, title="Image"):
    """
    Affiche la coupe centrale d'un volume 3D.
    """
    mid_slice = data.shape[2] // 2  # Coupe au milieu (axe Z)
    plt.imshow(data[:, :, mid_slice], cmap="gray")
    plt.title(title)
    plt.axis("off")
    plt.show()

# %%
# ------------------------------------
# 🔹 Parcours des patients et affichage
# ------------------------------------
def browse_results(results_dir):
    """
    Parcourt le dossier de résultats et affiche les images triées.
    """
    for patient in sorted(os.listdir(results_dir)):
        patient_path = os.path.join(results_dir, patient)
        if os.path.isdir(patient_path):
            print(f"--- Patient : {patient} ---")
            for timepoint in sorted(os.listdir(patient_path)):
                tp_path = os.path.join(patient_path, timepoint)
                if os.path.isdir(tp_path):
                    for file in os.listdir(tp_path):
                        if file.endswith(".nii.gz"):
                            file_path = os.path.join(tp_path, file)
                            data, _ = load_nifti(file_path)
                            print(f"Image chargée : {file_path} - Taille : {data.shape}")
                            display_middle_slice(data, title=f"{patient} - {timepoint} - {file}")

# %%
# ------------------------------------
# 🚀 Lancement de l'affichage
# ------------------------------------
browse_results(RESULTS_DIR)
# Out:
# --- Patient : PatientID_0003 ---
# Image chargée : /home/perfect/Documents/GitHub/projet-AI/data_filter/PatientID_0003/Timepoint_1/t2f_processed.nii.gz - Taille : (240, 240, 155)
# Image chargée : /home/perfect/Documents/GitHub/projet-AI/data_filter/PatientID_0003/Timepoint_1/t2w_processed.nii.gz - Taille : (240, 240, 155)
# Image chargée : /home/perfect/Documents/GitHub/projet-AI/data_filter/PatientID_0003/Timepoint_1/t1c_processed.nii.gz - Taille : (240, 240, 155)
# Image chargée : /home/perfect/Documents/GitHub/projet-AI/data_filter/PatientID_0003/Timepoint_1/tumorMask_processed.nii.gz - Taille : (240, 240, 155)
# Image chargée : /home/perfect/Documents/GitHub/projet-AI/data_filter/PatientID_0003/Timepoint_2/t2f_processed.nii.gz - Taille : (240, 240, 155)
# Image chargée : /home/perfect/Documents/GitHub/projet-AI/data_filter/PatientID_0003/Timepoint_2/t2w_processed.nii.gz - Taille : (240, 240, 155)
# Image chargée : /home/perfect/Documents/GitHub/projet-AI/data_filter/PatientID_0003/Timepoint_2/t1c_processed.nii.gz - Taille : (240, 240, 155)
# Image chargée : /home/perfect/Documents/GitHub/projet-AI/data_filter/PatientID_0003/Timepoint_2/tumorMask_processed.nii.gz - Taille : (240, 240, 155)
# Image chargée : /home/perfect/Documents/GitHub/projet-AI/data_filter/PatientID_0003/Timepoint_5/t2f_processed.nii.gz - Taille : (240, 240, 155)
# Image chargée : /home/perfect/Documents/GitHub/projet-AI/data_filter/PatientID_0003/Timepoint_5/t2w_processed.nii.gz - Taille : (240, 240, 155)
# Image chargée : /home/perfect/Documents/GitHub/projet-AI/data_filter/PatientID_0003/Timepoint_5/t1c_processed.nii.gz - Taille : (240, 240, 155)
# Image chargée : /home/perfect/Documents/GitHub/projet-AI/data_filter/PatientID_0003/Timepoint_5/tumorMask_processed.nii.gz - Taille : (240, 240, 155)
# --- Patient : PatientID_0006 ---
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[5], line 4
#       1 # ------------------------------------
#       2 # 🚀 Lancement de l'affichage
#       3 # ------------------------------------
# ----> 4 browse_results(RESULTS_DIR)
#
# Cell In[4], line 18, in browse_results(results_dir)
#      16 if file.endswith(".nii.gz"):
#      17     file_path = os.path.join(tp_path, file)
# ---> 18     data, _ = load_nifti(file_path)
#      19     print(f"Image chargée : {file_path} - Taille : {data.shape}")
#      20     display_middle_slice(data, title=f"{patient} - {timepoint} - {file}")
#
# Cell In[2], line 17, in load_nifti(file_path)
#      11 """
#      12 Charge un fichier NIfTI (.nii.gz) et retourne :
#      13 - data : tableau numpy (image)
#      14 - img : objet NIfTI (contient affine et header)
#      15 """
#      16 img = nib.load(file_path)
# ---> 17 data = img.get_fdata()
#      18 return data, img
#
# File ~/Documents/GitHub/projet-AI/env/lib/python3.10/site-packages/nibabel/dataobj_images.py:374, in DataobjImage.get_fdata(self, caching, dtype)
#     370         return self._fdata_cache
#     371 # Always return requested data type
#     372 # For array proxies, will attempt to confine data array to dtype
#     373 # during scaling
# --> 374 data = np.asanyarray(self._dataobj, dtype=dtype)
#     375 if caching == 'fill':
#     376     self._fdata_cache = data
#
# File ~/Documents/GitHub/projet-AI/env/lib/python3.10/site-packages/nibabel/arrayproxy.py:454, in ArrayProxy.__array__(self, dtype)
#     433 def __array__(self, dtype=None):
#     434     """Read data from file and apply scaling, casting to ``dtype``
#     435
#     436     If ``dtype`` is unspecified, the dtype of the returned array is the
#    (...)
#     452         Scaled image data with type `dtype`.
#     453     """
# --> 454     arr = self._get_scaled(dtype=dtype, slicer=())
#     455     if dtype is not None:
#     456         arr = arr.astype(dtype, copy=False)
#
# File ~/Documents/GitHub/projet-AI/env/lib/python3.10/site-packages/nibabel/arrayproxy.py:421, in ArrayProxy._get_scaled(self, dtype, slicer)
#     419     scl_inter = scl_inter.astype(use_dtype)
#     420 # Read array and upcast as necessary for big slopes, intercepts
# --> 421 scaled = apply_read_scaling(self._get_unscaled(slicer=slicer), scl_slope, scl_inter)
#     422 if dtype is not None:
#     423     scaled = scaled.astype(np.promote_types(scaled.dtype, dtype), copy=False)
#
# File ~/Documents/GitHub/projet-AI/env/lib/python3.10/site-packages/nibabel/arrayproxy.py:391, in ArrayProxy._get_unscaled(self, slicer)
#     387 if canonical_slicers(slicer, self._shape, False) == canonical_slicers(
#     388     (), self._shape, False
#     389 ):
#     390     with self._get_fileobj() as fileobj, self._lock:
# --> 391         return array_from_file(
#     392             self._shape,
#     393             self._dtype,
#     394             fileobj,
#     395             offset=self._offset,
#     396             order=self.order,
#     397             mmap=self._mmap,
#     398         )
#     399 with self._get_fileobj() as fileobj:
#     400     return fileslice(
#     401         fileobj,
#     402         slicer,
#    (...)
#     407         lock=self._lock,
#     408     )
#
# File ~/Documents/GitHub/projet-AI/env/lib/python3.10/site-packages/nibabel/volumeutils.py:467, in array_from_file(shape, in_dtype, infile, offset, order, mmap)
#     465 if hasattr(infile, 'readinto'):
#     466     data_bytes = bytearray(n_bytes)
# --> 467     n_read = infile.readinto(data_bytes)
#     468     needs_copy = False
#     469 else:
#
# File /usr/lib/python3.10/gzip.py:301, in GzipFile.read(self, size)
#     299     import errno
#     300     raise OSError(errno.EBADF, "read() on write-only GzipFile object")
# --> 301 return self._buffer.read(size)
#
# File /usr/lib/python3.10/_compression.py:68, in DecompressReader.readinto(self, b)
#      66 def readinto(self, b):
#      67     with memoryview(b) as view, view.cast("B") as byte_view:
# ---> 68         data = self.read(len(byte_view))
#      69         byte_view[:len(data)] = data
#      70     return len(data)
#
# File /usr/lib/python3.10/gzip.py:496, in _GzipReader.read(self, size)
#     493 # Read a chunk of data from the file
#     494 buf = self._fp.read(io.DEFAULT_BUFFER_SIZE)
# --> 496 uncompress = self._decompressor.decompress(buf, size)
#     497 if self._decompressor.unconsumed_tail != b"":
#     498     self._fp.prepend(self._decompressor.unconsumed_tail)
#
# KeyboardInterrupt:
