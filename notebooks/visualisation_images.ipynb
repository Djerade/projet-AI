# %% [markdown]
# # ================================================================
# # Notebook : Visualisation des images NIfTI triées
# # ================================================================

# %%
import os
import nibabel as nib
import matplotlib.pyplot as plt

# %%
# ------------------------------------
# 📌 Paramètres
# ------------------------------------
# Chemin vers ton dossier de résultats (à modifier selon ton PC)
RESULTS_DIR = "/home/perfect/Documents/GitHub/projet-AI/data_filter"

# ------------------------------------
# 🔹 Fonction pour charger un NIfTI
# ------------------------------------
def load_nifti(file_path):
    """
    Charge un fichier NIfTI (.nii.gz) et retourne :
    - data : tableau numpy (image)
    - img : objet NIfTI (contient affine et header)
    """
    img = nib.load(file_path)
    data = img.get_fdata()
    return data, img

# %%
# ------------------------------------
# 🔹 Fonction pour afficher une coupe centrale
# ------------------------------------
def display_middle_slice(data, title="Image"):
    """
    Affiche la coupe centrale d'un volume 3D.
    """
    mid_slice = data.shape[2] // 2  # Coupe au milieu (axe Z)
    plt.imshow(data[:, :, mid_slice], cmap="gray")
    plt.title(title)
    plt.axis("off")
    plt.show()

# %%
# ------------------------------------
# 🔹 Parcours des patients et affichage
# ------------------------------------
def browse_results(results_dir):
    """
    Parcourt le dossier de résultats et affiche les images triées.
    """
    for patient in sorted(os.listdir(results_dir)):
        patient_path = os.path.join(results_dir, patient)
        if os.path.isdir(patient_path):
            print(f"--- Patient : {patient} ---")
            for timepoint in sorted(os.listdir(patient_path)):
                tp_path = os.path.join(patient_path, timepoint)
                if os.path.isdir(tp_path):
                    for file in os.listdir(tp_path):
                        if file.endswith(".nii.gz"):
                            file_path = os.path.join(tp_path, file)
                            data, _ = load_nifti(file_path)
                            print(f"Image chargée : {file_path} - Taille : {data.shape}")
                            display_middle_slice(data, title=f"{patient} - {timepoint} - {file}")

# %%
# ------------------------------------
# 🚀 Lancement de l'affichage
# ------------------------------------
browse_results(RESULTS_DIR)
# Out:
# Image chargée : /home/perfect/Documents/GitHub/projet-AI/data_filter/PatientID_0013/Timepoint_4/t2w_processed.nii.gz - Taille : (240, 240, 155)
# Image chargée : /home/perfect/Documents/GitHub/projet-AI/data_filter/PatientID_0013/Timepoint_4/t1c_processed.nii.gz - Taille : (240, 240, 155)
# Image chargée : /home/perfect/Documents/GitHub/projet-AI/data_filter/PatientID_0013/Timepoint_4/tumorMask_processed.nii.gz - Taille : (240, 240, 155)
# --- Patient : PatientID_0014 ---
# Image chargée : /home/perfect/Documents/GitHub/projet-AI/data_filter/PatientID_0014/Timepoint_1/t2f_processed.nii.gz - Taille : (240, 240, 155)
# Image chargée : /home/perfect/Documents/GitHub/projet-AI/data_filter/PatientID_0014/Timepoint_1/t2w_processed.nii.gz - Taille : (240, 240, 155)
# Image chargée : /home/perfect/Documents/GitHub/projet-AI/data_filter/PatientID_0014/Timepoint_1/t1c_processed.nii.gz - Taille : (240, 240, 155)
# Image chargée : /home/perfect/Documents/GitHub/projet-AI/data_filter/PatientID_0014/Timepoint_1/tumorMask_processed.nii.gz - Taille : (240, 240, 155)
# Image chargée : /home/perfect/Documents/GitHub/projet-AI/data_filter/PatientID_0014/Timepoint_2/t2f_processed.nii.gz - Taille : (240, 240, 155)
# Image chargée : /home/perfect/Documents/GitHub/projet-AI/data_filter/PatientID_0014/Timepoint_2/t2w_processed.nii.gz - Taille : (240, 240, 155)
# Image chargée : /home/perfect/Documents/GitHub/projet-AI/data_filter/PatientID_0014/Timepoint_2/t1c_processed.nii.gz - Taille : (240, 240, 155)
# Image chargée : /home/perfect/Documents/GitHub/projet-AI/data_filter/PatientID_0014/Timepoint_2/tumorMask_processed.nii.gz - Taille : (240, 240, 155)
# Image chargée : /home/perfect/Documents/GitHub/projet-AI/data_filter/PatientID_0014/Timepoint_3/t2f_processed.nii.gz - Taille : (240, 240, 155)
# Image chargée : /home/perfect/Documents/GitHub/projet-AI/data_filter/PatientID_0014/Timepoint_3/t2w_processed.nii.gz - Taille : (240, 240, 155)
# Image chargée : /home/perfect/Documents/GitHub/projet-AI/data_filter/PatientID_0014/Timepoint_3/t1c_processed.nii.gz - Taille : (240, 240, 155)
# Image chargée : /home/perfect/Documents/GitHub/projet-AI/data_filter/PatientID_0014/Timepoint_3/tumorMask_processed.nii.gz - Taille : (240, 240, 155)
# --- Patient : PatientID_0018 ---
# Image chargée : /home/perfect/Documents/GitHub/projet-AI/data_filter/PatientID_0018/Timepoint_1/t2f_processed.nii.gz - Taille : (240, 240, 155)
# Image chargée : /home/perfect/Documents/GitHub/projet-AI/data_filter/PatientID_0018/Timepoint_1/t2w_processed.nii.gz - Taille : (240, 240, 155)
# Image chargée : /home/perfect/Documents/GitHub/projet-AI/data_filter/PatientID_0018/Timepoint_1/t1c_processed.nii.gz - Taille : (240, 240, 155)
# Image chargée : /home/perfect/Documents/GitHub/projet-AI/data_filter/PatientID_0018/Timepoint_1/tumorMask_processed.nii.gz - Taille : (240, 240, 155)
# Image chargée : /home/perfect/Documents/GitHub/projet-AI/data_filter/PatientID_0018/Timepoint_2/t2f_processed.nii.gz - Taille : (240, 240, 155)
# Image chargée : /home/perfect/Documents/GitHub/projet-AI/data_filter/PatientID_0018/Timepoint_2/t2w_processed.nii.gz - Taille : (240, 240, 155)
# Image chargée : /home/perfect/Documents/GitHub/projet-AI/data_filter/PatientID_0018/Timepoint_2/t1c_processed.nii.gz - Taille : (240, 240, 155)
# Image chargée : /home/perfect/Documents/GitHub/projet-AI/data_filter/PatientID_0018/Timepoint_2/tumorMask_processed.nii.gz - Taille : (240, 240, 155)
# Image chargée : /home/perfect/Documents/GitHub/projet-AI/data_filter/PatientID_0018/Timepoint_4/t2f_processed.nii.gz - Taille : (240, 240, 155)
# Image chargée : /home/perfect/Documents/GitHub/projet-AI/data_filter/PatientID_0018/Timepoint_4/t2w_processed.nii.gz - Taille : (240, 240, 155)
# Image chargée : /home/perfect/Documents/GitHub/projet-AI/data_filter/PatientID_0018/Timepoint_4/t1c_processed.nii.gz - Taille : (240, 240, 155)
# Image chargée : /home/perfect/Documents/GitHub/projet-AI/data_filter/PatientID_0018/Timepoint_4/tumorMask_processed.nii.gz - Taille : (240, 240, 155)
# --- Patient : PatientID_0019 ---
# Image chargée : /home/perfect/Documents/GitHub/projet-AI/data_filter/PatientID_0019/Timepoint_4/t2f_processed.nii.gz - Taille : (240, 240, 155)
# Image chargée : /home/perfect/Documents/GitHub/projet-AI/data_filter/PatientID_0019/Timepoint_4/t2w_processed.nii.gz - Taille : (240, 240, 155)
# Image chargée : /home/perfect/Documents/GitHub/projet-AI/data_filter/PatientID_0019/Timepoint_4/t1c_processed.nii.gz - Taille : (240, 240, 155)
# Image chargée : /home/perfect/Documents/GitHub/projet-AI/data_filter/PatientID_0019/Timepoint_4/tumorMask_processed.nii.gz - Taille : (240, 240, 155)
